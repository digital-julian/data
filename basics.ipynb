# %%
FILEPATH = "data/task_data/2021-11-22.json"
import json

from load_data import get_dataframe_from_json

with open(FILEPATH) as json_file:
    data = json.load(json_file)

# %%
# print out graph of exp over time
exp_df = get_dataframe_from_json(data['history']['exp'])
print("rough estimate of app usage over time:")
display(exp_df.plot())
# Out:
# rough estimate of app usage over time:
# <AxesSubplot:xlabel='date'>

# %%
exp_df = get_dataframe_from_json(data['history']['todos'])
print("rough estimate of todo procrastination:")
display(exp_df.plot())
# Out:
# rough estimate of todo procrastination:
# <AxesSubplot:xlabel='date'>

# %%
for task_type in ['habits', 'dailys', 'todos']:
    for task in data['tasks'][task_type]:
        print(task['text'], end='||')
# Out:
# Eat healthy / junk food||(+) stable / depressed (-) ||(+) stable / manic (-) ||Mj 🍁||Alcohol 🍺||Exercise||Tobacco||slept well / poorly||sex / masturbation||Tea / Krat||Tea / coffee ☕||Caffeine ☕||🌕 Lamotrigine 100mg||☀️Escitalopram 10mg||Guitar||Drums||# choices||# moods||# behaviors||Autob||decaf/caff||## symptoms||dizzy||Did a 💩||Drained the 🐍||Shower||Pelvic floor||# Timeshift||# drugs||<3hr||Earlier today||Yesterday||now||Diarr||Space cadet||sleepy||Apathy||Headache||Ooopsie||Gas :dash:||Runny nose :nose:||Creation 🌈||Nausea||Dissociative||Sore throat||Racing thoughts||Shaking||Heartburn :fire:||conjunctivitis||🌋acne breakout||Kratom||House/yardwork 🌱||⛅escitalopram 2.5mg||🖼️prawn||kava||fasting / overindulge||talkative / in head||morning 🪵/ed🥀||🪵sildenafil 10mg||Take Meds evening||Toothbrrz||Take meds morning||Water plants||Duolingo||Personal infomat. Conn w/ habitica||Pick up CMS swag||DEM files to server||Fix car||Fix scale||Water filter||Go to st pete utilities||Email Stephanie inat for xavier||Crypto||Attic fan setup||Paint car||Nature conservancy cancel||FIx 912 number||Peach Palm Google downgrade||Fix ac||mv auth keys||Rugs||mail Mike a SSD||set up monitoring for website||Fix front porch leak||Ghrsst add avhrr data||Homestead exemption||Plan trip to st Pete fairgrounds||check on fgbnms dash influx outage||fknms dash||mbon website products view||podaac download||NASA form||Abby pub form||balloon fest tickets||research interpolation methods||new hsa card||register car in FL||change HSA contribution||dentist appt||fix guitar||text mandy "how you" ASL video||fix dune & ERDDAP server||repot plants||new bed frame||ocean sciences workshop github||get pumpkins & carving tools||send chemtax email||trim nails||cash from bank||dispensary||wrap gifts for Veronica||door batteries||geo4good poster submission||check on laptop request||
